# %% [markdown]
# # random
# randint rand choice shuffle permutation normal binomial poisson uniform

# %%
from numpy import random
import numpy as np

# %%
# randint
x = random.randint(10)
print(x)
print()
x=random.randint(100, size=(5))
print(x)
print()
x = random.randint(100, size=(3, 5))
print(x)
# Out:
# 1
#
# [58 97 69 88 45]
#
# [[ 3 26 65 65  4]
#  [61 32 21 89 62]
#  [40 50 46 67 73]]

# %%
# rand
x = random.rand()
print(x)
print()
print(int(x*10))
print()
x = random.rand(5)
print(x)
print()
x = random.rand(3, 5)
print(x)
# Out:
# 0.4427631007588564
#
# 4
#
# [0.8367587  0.90913302 0.58057968 0.9028289  0.56897936]
#
# [[0.97416143 0.03851333 0.61824316 0.24406467 0.65652525]
#  [0.51239932 0.14378139 0.48326208 0.65248984 0.59626193]
#  [0.70910377 0.81346826 0.04163286 0.5611357  0.15006919]]

# %%
# choice
x = random.choice([3, 5, 7, 9])
print(x)
print()
x = random.choice([0,1], size=(3, 4))
print(x)
print()
# p for probability
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(3, 5)) 
print(x)
# Out:
# 5
#
# [[0 0 1 1]
#  [0 0 0 1]
#  [0 0 0 1]]
#
# [[7 7 5 5 7]
#  [7 5 7 7 7]
#  [7 5 3 5 7]]

# %%
# shuffle
arr = np.array([1, 2, 3, 4, 5])
random.shuffle(arr)
print(arr)
# Out:
# [3 4 2 1 5]

# %%
# permutation
arr = np.array([1, 2, 3, 4, 5])
print(random.permutation(arr))
# Out:
# [5 4 3 2 1]

# %%
# normal
x = random.normal()
print(x)
print()
x = random.normal(size=(2, 3))
print(x)
print()
x = random.normal(loc=1, scale=2, size=(2, 3))
print(x)
# Out:
# 2.4750801460132683
#
# [[-1.23916777 -0.55708831 -0.43309492]
#  [-0.66161269 -1.74582042  0.20904814]]
#
# [[-2.08234726  1.80197309  3.80149121]
#  [ 0.54849776 -1.29950599  4.85025544]]

# %%
# binomial
x = random.binomial(n=10, p=0.5, size=10)
print(x)
# Out:
# [7 6 3 6 7 4 3 4 6 3]

# %%
# poisson
x = random.poisson(lam=2, size=10)
print(x)
# Out:
# [1 3 5 4 3 2 3 2 1 1]

# %%
# uniform
x = random.uniform(size=(2, 3))
print(x)

# %% [markdown]
# # seaborn
# distplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0, 1, 2, 3, 4, 5]) # hist=True
plt.show()
# Out:
# C:\Users\Harish\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot([0, 1, 2, 3, 4, 5], hist=False)
plt.show()
# Out:
# C:\Users\Harish\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(random.normal(size=1000), hist=False)

plt.show()
# Out:
# C:\Users\Harish\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)
plt.show()

# %%
sns.distplot(random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')

plt.show()
# Out:
# C:\Users\Harish\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Harish\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(random.poisson(lam=2, size=1000), kde=False)

plt.show()

# %%
sns.distplot(random.normal(loc=50, scale=7, size=1000), hist=False, label='normal')
sns.distplot(random.poisson(lam=50, size=1000), hist=False, label='poisson')

plt.show()
# Out:
# C:\Users\Harish\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Harish\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(random.uniform(size=1000), hist=False)

plt.show()
# Out:
# C:\Users\Harish\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
